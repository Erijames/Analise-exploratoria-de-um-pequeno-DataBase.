# %%
#Importando todas as  bibliotecas para a analise

# Generaal syntax to import specific  functions in a library:
#from (library) import (speecific  library function)

from pandas import DataFrame , read_csv


#Generaal syntax to import a library  but no functions:
#from (library) as (give the library a nickknamme/alias)
import matplotlib.pyplot as  plt
import pandas as pd
import sys #onlyy needed to determine Matplotlib version number

#Enable inline plotting

# %matplotlib inline

# %%
# Dta set inicial
names = ['Bob','Jessica', 'Mary', 'Jonh', 'Mel']
births = [968,155,77,578,973]

# %%
# Utilizamos a função zip para juntar as duas listas 

BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('Jonh', 578), ('Mel', 973)]

# %%
df = pd.DataFrame(data = BabyDataSet, columns  = ['Names','Births'] )
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     Jonh     578
# 4      Mel     973

# %%
# colocamos na ordem e vemos o nome com maior valor
sorted = df.sort_values(['Births'], ascending=False)
sorted.head(1)
# Out:
#   Names  Births
# 4   Mel     973

# %%
#coletamos o maior valor de nascimentos
df['Births'].max()
# Out:
# 973

# %%
# Criar um grafico 

df['Births'].plot()

#maior valor no data set
Maxvalues = df['Births'].max()

#nome associado com maior valor 
Maxname = df['Names'][df['Births'] == df['Births'].max()].values

print('O nome mais popular e´: ')
df[df['Births'] == df['Births'].max()]
# Out:
# O nome mais popular e´:
#   Names  Births
# 4   Mel     973
